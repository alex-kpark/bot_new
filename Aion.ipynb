# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
column = [
    'time',
    'actor_account_id',
    'actor_id',
    'serverno',
    'total_kina',
    'inven_kina',
    'warehouse_kina',
    'solo_rooting',
    'party_rooting',
    'sell_npc',
    'quest_complete',
    'post_present',
    'sell_agencies',
    'guild_emblem',
    'sell_agencies_caculate',
    'arena_reward',
    'disposal_item',
    'default_value',
    'buy_npc',
    'post',
    'delete_option',
    'teleport',
    'vendor_buy',
    'expand_inven',
    'quest',
    'gather_skill_up',
    'vendor_fee',
    'item_charge',
    'auction_bet',
    'housing_charge',
    'auction_register',
    'use_hotspot',
    'stigma',
    'disassemply',
    'extract',
    'dye',
    'minion_growth',
    'minion_evolution',
    'minion_synthesis',
    'reinforce',
    'stigma_reinforce',
    'ma_stone_reinforce',
    'sin_stone_reinforce',
    'idian',
    'breakthrough',
    'transform_synthesis',
    'retune',
    'devanion_reinforce',
    'devanion_synthesis'
    ]

label_col = [
    'date',
    'actor_id',
    'actor_account_id',
    'label'
]

# %%
data_path = 'D:/NC/data_an/an_money.csv'
label_path = 'D:/NC/data_an/an_label.csv'

# %%
data = pd.read_csv(data_path, names=column)
data = pd.DataFrame(data)

# %%
answer = pd.read_csv(label_path, names=label_col)
answer = pd.DataFrame(answer)

# %%
s = answer[answer['label']==1.0]
s[s['actor_account_id']=='e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3de6dbdda5f0f9e67fb9']
# Out:
#            date                                           actor_id  \
# 220  2019-03-07  21f309cf11283090ae2ffbd22e63c53dfe979333077b88...
# 221  2019-03-08  21f309cf11283090ae2ffbd22e63c53dfe979333077b88...
#
#                                       actor_account_id  label
# 220  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...    1.0
# 221  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...    1.0

# %%
data[data['actor_account_id']=='e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3de6dbdda5f0f9e67fb9']
# Out:
#                   time                                   actor_account_id  \
# 2497071  2019-03-07 19  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2838755  2019-03-07 11  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2846681  2019-03-07 10  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2847641  2019-03-08 01  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2852503  2019-03-08 00  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2860269  2019-03-07 12  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 2871307  2019-03-08 02  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 3794883  2019-03-07 13  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 3802734  2019-03-08 03  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 4104752  2019-03-07 17  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 4110446  2019-03-08 07  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# 4290056  2019-03-07 21  e3cf78806bb8037148f2d7bcc9b3c4ac2f97ba930abd3d...
# ...
